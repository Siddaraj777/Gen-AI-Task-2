# %%
# ==========================================
# LANGCHAIN ALL-IN-ONE ASSIGNMENT CODE
# FULL PDF PATH VERSION
# ==========================================

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_classic.memory import ConversationBufferMemory
from langchain_classic.chains import LLMChain, RetrievalQA
from langchain_classic.agents import Tool, initialize_agent
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
import os

# ==========================================
# API KEY
# ==========================================
os.environ["OPENAI_API_KEY"] = "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"

# ==========================================
# 1) BASIC LLM CALL
# ==========================================
print("===== BASIC LLM CALL =====")

llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0.7
)

response = llm.invoke("What is LangChain?")
print(response.content)

# ==========================================
# 2) PROMPT TEMPLATE
# ==========================================
print("\n===== PROMPT TEMPLATE =====")

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in 3 simple points"
)

print(prompt.format(topic="Machine Learning"))

# ==========================================
# 3) SIMPLE CHAIN
# ==========================================
print("\n===== SIMPLE CHAIN =====")

chain = LLMChain(llm=llm, prompt=prompt)
print(chain.run("LangChain"))

# ==========================================
# 4) MEMORY
# ==========================================
print("\n===== MEMORY =====")

memory = ConversationBufferMemory()
memory.save_context(
    {"input": "My name is Siddaraj"},
    {"output": "Nice to meet you"}
)
print(memory.load_memory_variables({}))

# ==========================================
# 5) AGENT + TOOL
# ==========================================
print("\n===== AGENT =====")

def square_tool(x):
    return str(int(x) ** 2)

tools = [
    Tool(
        name="SquareTool",
        func=square_tool,
        description="Returns square of a number"
    )
]

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="zero-shot-react-description"
)

print(agent.run("What is square of 12?"))

# ==========================================
# 6) PDF LOADER + FAISS + QA
# ==========================================
print("\n===== PDF LOADER =====")

# PASTE YOUR COPIED FULL PDF PATH HERE
pdf_path = r"C:\Users\dell\Downloads\LangChain Deep Technical Blog (Blog Writing Task).pdf"

try:
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    print(f"Loaded {len(documents)} pages from PDF")

    print("\n===== VECTOR STORE =====")
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(documents, embeddings)
    print("FAISS created successfully")

    print("\n===== RETRIEVAL QA =====")
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=vectorstore.as_retriever()
    )

    answer = qa_chain.run("Give a summary of the main points in this document")
    print(answer)

except Exception as e:
    print("PDF loading failed:", e)

# ==========================================
# FINAL MESSAGE
# ==========================================
print("\n===== ALL TASKS COMPLETED SUCCESSFULLY =====")
# Out:
# ===== BASIC LLM CALL =====
# LangChain is an open-source framework designed to help developers build applications that integrate large language models (LLMs) with other data sources and computational tools. It provides a suite of modular components and abstractions to simplify the creation of complex workflows involving LLMs, such as chatbots, question-answering systems, document analysis tools, and more.
#
# Key features of LangChain include:
#
# - **Chains:** Components that allow you to link together multiple calls to language models or other utilities in a sequence or graph-like structure.
# - **Prompts:** Tools to manage and format prompts sent to LLMs, enabling prompt templates and dynamic prompt creation.
# - **Agents:** Systems that can decide which actions to take (e.g., querying a database, calling an API) based on user input and context, often involving reasoning.
# ...

# %%
# ==========================================
# LANGCHAIN ALL-IN-ONE GITHUB SAFE CODE
# ==========================================

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_classic.memory import ConversationBufferMemory
from langchain_classic.chains import LLMChain, RetrievalQA
from langchain_classic.agents import Tool, initialize_agent
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
import os

# ==========================================
# LOAD API KEY SECURELY FROM .env
# ==========================================
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("OPENAI_API_KEY not found in .env file")

# ==========================================
# 1) BASIC LLM CALL
# ==========================================
print("===== BASIC LLM CALL =====")

llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0.7
)

response = llm.invoke("What is LangChain?")
print(response.content)

# ==========================================
# 2) PROMPT TEMPLATE
# ==========================================
print("\n===== PROMPT TEMPLATE =====")

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in 3 simple points"
)

print(prompt.format(topic="Machine Learning"))

# ==========================================
# 3) SIMPLE CHAIN
# ==========================================
print("\n===== SIMPLE CHAIN =====")

chain = LLMChain(llm=llm, prompt=prompt)
print(chain.run("LangChain"))

# ==========================================
# 4) MEMORY
# ==========================================
print("\n===== MEMORY =====")

memory = ConversationBufferMemory()
memory.save_context(
    {"input": "My name is Siddaraj"},
    {"output": "Nice to meet you"}
)
print(memory.load_memory_variables({}))

# ==========================================
# 5) AGENT + TOOL
# ==========================================
print("\n===== AGENT =====")

def square_tool(x):
    return str(int(x) ** 2)

tools = [
    Tool(
        name="SquareTool",
        func=square_tool,
        description="Returns square of a number"
    )
]

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="zero-shot-react-description"
)

print(agent.run("What is square of 12?"))

# ==========================================
# 6) PDF LOADER + VECTOR STORE + QA
# ==========================================
print("\n===== PDF LOADER =====")

pdf_path = r"C:\Users\Siddaraj\Downloads\sample.pdf"

try:
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    print(f"Loaded {len(documents)} pages from PDF")

    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(documents, embeddings)

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=vectorstore.as_retriever()
    )

    answer = qa_chain.run(
        "What are the main tasks mentioned in this assignment?"
    )
    print(answer)

except Exception as e:
    print("PDF loading failed:", e)

# ==========================================
# FINAL MESSAGE
# ==========================================
print("\n===== ALL TASKS COMPLETED SUCCESSFULLY =====")
# Out:
# ===== BASIC LLM CALL =====
# LangChain is an open-source framework designed to simplify the development of applications that use large language models (LLMs). It provides tools and abstractions to help developers build complex workflows by chaining together different components such as prompts, LLMs, data sources, and memory. This enables the creation of sophisticated applications like chatbots, question-answering systems, document analysis tools, and more.
#
# Key features of LangChain include:
#
# - **Prompt Management:** Tools to create, manage, and optimize prompts for LLMs.
# - **Chains:** Ability to link multiple calls to LLMs or other utilities into a sequence or graph to perform multi-step reasoning or operations.
# - **Memory:** Support for maintaining state or context across interactions, useful for conversational AI.
# - **Integrations:** Connectors for various data sources (databases, APIs, document stores) and external tools.
# ...
